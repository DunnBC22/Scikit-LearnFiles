# %%
'''
Before beginning, I want to thank Rylan Fowers for the assistance. 
The video (https://www.youtube.com/watch?v=b0L47BeklTE) was a great help.

Ordinary Least Squares (OLS) Linear Regression

Dataset: https://www.kaggle.com/parteekbhatia/dataset-for-simple-linear-regression
'''

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

data = pd.read_csv("~/Desktop/Sklearn Data Sets/SimpleLinearRegressionData/SimpleLRData.csv")
print(data.info())
print(data.head())

data.plot(kind="scatter", x="ResearchExperience", y="Stipend")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ResearchExperience  30 non-null     float64
#  1   Stipend             30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes
# None
#    ResearchExperience  Stipend
# 0                 1.1    39343
# 1                 1.3    46205
# 2                 1.5    37731
# 3                 2.0    43525
# 4                 2.2    39891

# %%
# Test train split for supervised learning
X_train, X_test, y_train, y_test = train_test_split(data.ResearchExperience, data.Stipend)

# %%
#test train visualization
plt.scatter(X_train, y_train, label="Training Data", color='r', alpha=.7)
plt.scatter(X_test, y_test, label="Testing Data", color='g', alpha=.7)
plt.legend()
plt.title("Test Train Split")
plt.show()

# %%
# Create linear model and train it
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1), y_train.values)
# Out:
# LinearRegression()

# %%
#Use model to predict on the TEST data
prediction = LR.predict(X_test.values.reshape(-1,1))

# plot the prediction line against the actual test data
plt.plot(X_test, prediction, label="Linear Regression",  color='b')
plt.scatter(X_test, y_test, label="Actual Test Data", color='g', alpha=.7)
plt.legend()
plt.show()

# %%
#predict the Stipend for someone with 5 years of ResearchExperience
LR.predict(np.array([[5]]))[0]
# Out:
# 72540.39223761667

# %%
#score it
LR.score(X_test.values.reshape(-1,1), y_test.values)
# Out:
# 0.8899596063197988

# %%
LR.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
LR.coef_[0]
print("The coefficient is:", LR.coef_[0])
LR.intercept_
print("The intercept for this Linear Regression is:", LR.intercept_)
# Out:
# The coefficient is: 9829.566717152493
# The intercept for this Linear Regression is: 23392.55865185422
